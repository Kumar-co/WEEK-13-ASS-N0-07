# %% [markdown]
# WEEK-13, ASS NO- 07

# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.

# %% [markdown]
# To calculate Spearman's rank correlation coefficient between the amount of sleep individuals get each night and their overall job satisfaction level, we'll first create a hypothetical dataset. Spearman's correlation measures the strength and direction of the monotonic relationship between two variables.
#
# ### Hypothetical Dataset
#
# Let's assume we have the following data representing the number of hours of sleep and corresponding job satisfaction levels:
#
# | Hours of Sleep | Job Satisfaction |
# |----------------|------------------|
# | 4              | 3                |
# | 5              | 5                |
# | 6              | 7                |
# | 7              | 8                |
# | 8              | 9                |
# | 3              | 2                |
# | 9              | 10               |
# | 2              | 1                |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.

# %% [markdown]
# To calculate both the Pearson correlation coefficient and the Spearman's rank correlation between the number of hours of exercise per week and body mass index (BMI), we will first create a hypothetical dataset. This dataset will contain the exercise hours and BMI values for 50 participants.
#
# ### Hypothetical Dataset
#
# Let's assume we have the following data representing the number of hours of exercise per week and corresponding BMI values:
#
# | Hours of Exercise | BMI  |
# |-------------------|------|
# | 0                 | 30   |
# | 1                 | 29   |
# | 2                 | 28   |
# | 2                 | 27   |
# | 3                 | 26   |
# | 3                 | 25   |
# | 4                 | 24   |
# | 4                 | 23   |
# | 5                 | 22   |
# | 5                 | 21   |
# | 6                 | 20   |
# | 6                 | 19   |
# | 7                 | 18   |
# | 7                 | 17   |
# | 8                 | 16   |
# | 8                 | 15   |
# | 9                 | 14   |
# | 9                 | 13   |
# | 10                | 12   |
# | 10                | 11   |
# | 11                | 10   |
# | 11                | 9    |
# | 12                | 8    |
# | 12                | 7    |
# | 13                | 6    |
# | 13                | 5    |
# | 14                | 4    |
# | 14                | 3    |
# | 15                | 2    |
# | 15                | 1    |
# | 0                 | 31   |
# | 1                 | 30   |
# | 2                 | 29   |
# | 2                 | 28   |
# | 3                 | 27   |
# | 3                 | 26   |
# | 4                 | 25   |
# | 4                 | 24   |
# | 5                 | 23   |
# | 5                 | 22   |
# | 6                 | 21   |
# | 6                 | 20   |
# | 7                 | 19   |
# | 7                 | 18   |
# | 8                 | 17   |
# | 8                 | 16   |
# | 9                 | 15   |
# | 9                 | 14   |
# | 10                | 13   |
# | 10                | 12   |
# | 11                | 11   |
# | 11                | 10   |
# | 12                | 9    |
# | 12                | 8    |
# | 13                | 7    |
# | 13                | 6    |
# | 14                | 5    |
# | 14                | 4    |
# | 15                | 3    |
# | 15                | 2    |
#
# This dataset contains a mix of exercise hours and corresponding BMI values for 50 participants.
#
# ### Steps to Calculate Correlations
#
# 1. **Pearson Correlation**: Calculate using the formula for Pearson correlation.
# 2. **Spearman Rank Correlation**: Calculate using the ranks of the data.
# 3. **Compare Results**: Analyze the differences in correlation values and their implications.

# %% [markdown]
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.

# %% [markdown]
# To calculate the Pearson correlation coefficient between the number of hours individuals spend watching television per day and their level of physical activity, we need to create a hypothetical dataset. The Pearson correlation coefficient will measure the strength and direction of the linear relationship between these two continuous variables.
#
# ### Hypothetical Dataset
#
# Let's assume we have the following data representing the number of hours spent watching television and the corresponding level of physical activity (measured in hours of exercise per week) for 50 participants:
#
# | Hours Watching TV | Hours of Physical Activity |
# |-------------------|----------------------------|
# | 5                 | 1                          |
# | 4                 | 2                          |
# | 6                 | 0                          |
# | 3                 | 3                          |
# | 2                 | 4                          |
# | 7                 | 0                          |
# | 1                 | 5                          |
# | 4                 | 2                          |
# | 5                 | 1                          |
# | 3                 | 3                          |
# | 2                 | 4                          |
# | 8                 | 0                          |
# | 3                 | 3                          |
# | 2                 | 4                          |
# | 6                 | 1                          |
# | 5                 | 2                          |
# | 4                 | 3                          |
# | 5                 | 1                          |
# | 3                 | 3                          |
# | 2                 | 4                          |
# | 1                 | 5                          |
# | 4                 | 2                          |
# | 7                 | 0                          |
# | 8                 | 1                          |
# | 6                 | 1                          |
# | 3                 | 2                          |
# | 4                 | 3                          |
# | 5                 | 1                          |
# | 6                 | 0                          |
# | 2                 | 4                          |
# | 3                 | 3                          |
# | 4                 | 2                          |
# | 2                 | 5                          |
# | 1                 | 6                          |
# | 8                 | 0                          |
# | 5                 | 2                          |
# | 4                 | 3                          |
# | 3                 | 4                          |
# | 2                 | 5                          |
# | 1                 | 6                          |
# | 5                 | 1                          |
# | 4                 | 2                          |
# | 3                 | 3                          |
# | 6                 | 0                          |
# | 5                 | 2                          |
# | 4                 | 3                          |
# | 7                 | 0                          |
# | 8                 | 1                          |
# | 3                 | 2                          |
# | 2                 | 5                          |
# | 1                 | 6                          |
# | 6                 | 1                          |
# | 5                 | 2                          |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Thank you for providing the survey results! We can analyze the relationship between age and soft drink preference using the data you've shared.
#
# ### Data Summary
#
# - **Ages**: 25, 42, 37, 19, 31, 28
# - **Soft Drink Preferences**: Coke, Pepsi, Mountain Dew, Coke, Pepsi, Coke
#
# ### Data Organization
#
# Let's organize the data for easier analysis:
#
# | Age | Soft Drink Preference |
# |-----|-----------------------|
# | 25  | Coke                  |
# | 42  | Pepsi                 |
# | 37  | Mountain Dew          |
# | 19  | Coke                  |
# | 31  | Pepsi                 |
# | 28  | Coke                  |
#
# ### Analysis
#
# We can perform the following analyses:
#
# 1. **Count Preferences**: Count how many individuals of each age group prefer each brand.
# 2. **Visualization**: Create a bar chart or another visualization to show the preferences by age.
# 3. **Correlation**: Analyze the relationship between age and preference (if applicable).
#
# ### Steps for Analysis
#
# Let’s first create a frequency table to summarize the preferences based on age.
#
# Here's a simple count of preferences:
#
# - **Coke**: 4 preferences (ages 25, 19, 28)
# - **Pepsi**: 2 preferences (ages 42, 31)
# - **Mountain Dew**: 1 preference (age 37)

# %% [markdown]
# Q6. A company is interested in examining the relationship between the number of sales calls made per day
# and the number of sales made per week. The company collected data on both variables from a sample of
# 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %% [markdown]
# To calculate the Pearson correlation coefficient between the number of sales calls made per day and the number of sales made per week, we first need to create a hypothetical dataset for the 30 sales representatives.
#
# ### Hypothetical Dataset
#
# Let's assume we have the following data representing the number of sales calls made per day and the corresponding number of sales made per week:
#
# | Sales Calls per Day | Sales Made per Week |
# |---------------------|---------------------|
# | 20                  | 5                   |
# | 25                  | 6                   |
# | 15                  | 3                   |
# | 30                  | 8                   |
# | 10                  | 2                   |
# | 28                  | 7                   |
# | 22                  | 5                   |
# | 18                  | 4                   |
# | 26                  | 6                   |
# | 24                  | 7                   |
# | 27                  | 8                   |
# | 19                  | 5                   |
# | 21                  | 6                   |
# | 23                  | 7                   |
# | 29                  | 9                   |
# | 32                  | 10                  |
# | 17                  | 4                   |
# | 16                  | 3                   |
# | 14                  | 2                   |
# | 13                  | 1                   |
# | 12                  | 2                   |
# | 11                  | 3                   |
# | 9                   | 1                   |
# | 8                   | 0                   |
# | 7                   | 1                   |
# | 6                   | 0                   |
# | 5                   | 0                   |
# | 4                   | 0                   |
# | 3                   | 0                   |
# | 2                   | 0                   |
# | 1                   | 0                   |
#
# ### Steps to Calculate the Pearson Correlation Coefficient
#
# 1. **Input the data**: Organize the dataset for analysis.
# 2. **Calculate the Pearson correlation coefficient**: Use the formula for Pearson correlation.
